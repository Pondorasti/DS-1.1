# %% [markdown]
# So far we have learned about several different pandas commands and visualization techniques, now let's put those into more practice!

# %% [markdown]
# A dataframe is one of the most important data structures included in the pandas library. You can think of dataframes as fancy excel tables. They store data in row and column format and let you easily manipulate large amounts of data.
#
# pandas comes with a built in function called read_csv() that let's use easily convert a CSV file to a dataframe
#
# For info about read_csv() check out [this article](https://www.datacamp.com/community/tutorials/pandas-read-csv)

# %%
import pandas as pd
dataurl = "datasets/AppleStore.csv"
#TODO: store the data in a dataframe using read_csv
df = pd.read_csv(dataurl)
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# 7192                                              Kubik   126644224      USD
# 7193                                  VR Roller-Coaster   120760320      USD
# 7194              Bret Michaels Emojis + Lyric Keyboard   111322112      USD
# 7195          VR Roller Coaster World - Virtual Reality    97235968      USD
# 7196                       Escape the Sweet Shop Series    90898432      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0      3.99             21292                26          4.0              4.5
# 1      0.00            161065                26          4.0              3.5
# 2      0.00            188583              2822          3.5              4.5
# 3      0.00            262241               649          4.0              4.5
# 4      0.00            985920              5320          4.5              5.0
# ...     ...               ...               ...          ...              ...
# 7192   0.00               142                75          4.5              4.5
# 7193   0.00                30                30          4.5              4.5
# 7194   1.99                15                 0          4.5              0.0
# 7195   0.00                85                32          4.5              4.5
# 7196   0.00                 3                 3          5.0              5.0
#
#          ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 0      6.3.5          4+         Games               38                5
# 1      8.2.2          4+  Productivity               37                5
# 2      5.0.0          4+       Weather               37                5
# 3     5.10.0         12+      Shopping               37                5
# 4      7.5.1          4+     Reference               37                5
# ...      ...         ...           ...              ...              ...
# 7192     1.3          4+         Games               38                5
# 7193     0.9          4+         Games               38                0
# 7194   1.0.2          9+     Utilities               37                1
# 7195  1.0.15         12+         Games               38                0
# 7196     1.0          4+         Games               40                0
#
#       lang.num  vpp_lic
# 0           10        1
# 1           23        1
# 2            3        1
# 3            9        1
# 4           45        1
# ...        ...      ...
# 7192         1        1
# 7193         1        1
# 7194         1        1
# 7195         2        1
# 7196         2        1
#
# [7197 rows x 17 columns]

# %% [markdown]
# To quickly look at the first and last n columns pandas includes two methods of a dataframe called head() and tail() these methods take one integer argument and let you look at the first and last n rows respectively
#
# For more info about these methods check out [this
# article](https://note.nkmk.me/en/python-pandas-head-tail/)

# %%
#TODO: look at the first 5 rows and the last 10
df[0:19]
# Out:
#     Unnamed: 0         id                                         track_name  \
# 0            1  281656475                                    PAC-MAN Premium
# 1            2  281796108                          Evernote - stay organized
# 2            3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3            4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4            5  282935706                                              Bible
# 5            6  283619399                                   Shanghai Mahjong
# 6            7  283646709             PayPal - Send and request money safely
# 7            8  284035177                            Pandora - Music & Radio
# 8            9  284666222                        PCalc - The Best Calculator
# 9           10  284736660                                        Ms. PAC-MAN
# 10          11  284791396                          Solitaire by MobilityWare
# 11          12  284815117                                   SCRABBLE Premium
# 12          13  284815942               Google – Search made just for mobile
# 13          14  284847138                   Bank of America - Mobile Banking
# 14          15  284862767                                           FreeCell
# 15          16  284876795             TripAdvisor Hotels Flights Restaurants
# 16          17  284882215                                           Facebook
# 17          18  284910350     Yelp - Nearby Restaurants, Shopping & Services
# 18          20  284993459  Shazam - Discover music, artists, videos & lyrics
#
#     size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0    100788224      USD   3.99             21292                26
# 1    158578688      USD   0.00            161065                26
# 2    100524032      USD   0.00            188583              2822
# 3    128512000      USD   0.00            262241               649
# 4     92774400      USD   0.00            985920              5320
# 5     10485713      USD   0.99              8253              5516
# 6    227795968      USD   0.00            119487               879
# 7    130242560      USD   0.00           1126879              3594
# 8     49250304      USD   9.99              1117                 4
# 9     70023168      USD   3.99              7885                40
# 10    49618944      USD   4.99             76720              4017
# 11   227547136      USD   7.99            105776               166
# 12   179979264      USD   0.00            479440               203
# 13   160925696      USD   0.00            119773              2336
# 14    55153664      USD   4.99              6340               668
# 15   207907840      USD   0.00             56194                87
# 16   389879808      USD   0.00           2974676               212
# 17   167407616      USD   0.00            223885              3726
# 18   147093504      USD   0.00            402925               136
#
#     user_rating  user_rating_ver      ver cont_rating        prime_genre  \
# 0           4.0              4.5    6.3.5          4+              Games
# 1           4.0              3.5    8.2.2          4+       Productivity
# 2           3.5              4.5    5.0.0          4+            Weather
# 3           4.0              4.5   5.10.0         12+           Shopping
# 4           4.5              5.0    7.5.1          4+          Reference
# 5           4.0              4.0      1.8          4+              Games
# 6           4.0              4.5   6.12.0          4+            Finance
# 7           4.0              4.5    8.4.1         12+              Music
# 8           4.5              5.0    3.6.6          4+          Utilities
# 9           4.0              4.0    4.0.4          4+              Games
# 10          4.5              4.5   4.10.1          4+              Games
# 11          3.5              2.5   5.19.0          4+              Games
# 12          3.5              4.0     27.0         17+          Utilities
# 13          3.5              4.5    7.3.8          4+            Finance
# 14          4.5              4.5    4.0.3          4+              Games
# 15          4.0              3.5     21.1          4+             Travel
# 16          3.5              3.5     95.0          4+  Social Networking
# 17          4.0              4.5  11.15.0         12+             Travel
# 18          4.0              4.5   11.0.3         12+              Music
#
#     sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0                38                5        10        1
# 1                37                5        23        1
# 2                37                5         3        1
# 3                37                5         9        1
# 4                37                5        45        1
# 5                47                5         1        1
# 6                37                0        19        1
# 7                37                4         1        1
# 8                37                5         1        1
# 9                38                0        10        1
# 10               38                4        11        1
# 11               37                0         6        1
# 12               37                4        33        1
# 13               37                0         2        1
# 14               38                5         2        1
# 15               37                1        26        1
# 16               37                1        29        1
# 17               37                5        18        1
# 18               37                3        16        1

# %% [markdown]
# Pandas dataframes both use bracket [] and dot . notation to easily access columns
#
#
#
# ```
# df["column_name"] or df.column_name
# ```
#
# [bracket notation is much more flexible](https://www.dunderdata.com/blog/use-the-brackets-to-select-a-single-pandas-dataframe-column-and-not-dot-notation) than dot, you can use [] notation to slice the data frame, access multiple columns at once, and set new columns
#
# ```
# df[start:stop]
# df[["column1", "column2"]]
# df["new_column"] = new_data
# ```

# %%
#TODO: select the 3rd row up to the 20th row in the dataframe
df[2:19]
#TODO: select the user_rating, price, and track_name columns
df[["user_rating", "price", "track_name"]]
#TODO: create a new column called "test" that just has all 0's
df["test"] = 0
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# 7192                                              Kubik   126644224      USD
# 7193                                  VR Roller-Coaster   120760320      USD
# 7194              Bret Michaels Emojis + Lyric Keyboard   111322112      USD
# 7195          VR Roller Coaster World - Virtual Reality    97235968      USD
# 7196                       Escape the Sweet Shop Series    90898432      USD
#
#       price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0      3.99             21292                26          4.0              4.5
# 1      0.00            161065                26          4.0              3.5
# 2      0.00            188583              2822          3.5              4.5
# 3      0.00            262241               649          4.0              4.5
# 4      0.00            985920              5320          4.5              5.0
# ...     ...               ...               ...          ...              ...
# 7192   0.00               142                75          4.5              4.5
# 7193   0.00                30                30          4.5              4.5
# 7194   1.99                15                 0          4.5              0.0
# 7195   0.00                85                32          4.5              4.5
# 7196   0.00                 3                 3          5.0              5.0
#
#          ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 0      6.3.5          4+         Games               38                5
# 1      8.2.2          4+  Productivity               37                5
# 2      5.0.0          4+       Weather               37                5
# 3     5.10.0         12+      Shopping               37                5
# 4      7.5.1          4+     Reference               37                5
# ...      ...         ...           ...              ...              ...
# 7192     1.3          4+         Games               38                5
# 7193     0.9          4+         Games               38                0
# 7194   1.0.2          9+     Utilities               37                1
# 7195  1.0.15         12+         Games               38                0
# 7196     1.0          4+         Games               40                0
#
#       lang.num  vpp_lic  test
# 0           10        1     0
# 1           23        1     0
# 2            3        1     0
# 3            9        1     0
# 4           45        1     0
# ...        ...      ...   ...
# 7192         1        1     0
# 7193         1        1     0
# 7194         1        1     0
# 7195         2        1     0
# 7196         2        1     0
#
# [7197 rows x 18 columns]

# %% [markdown]
# loc and iloc are useful methods for selecting columns of a data frame based on label in the case of loc and integer position in the case of iloc (note that both use bracket notation). To make the difference clear we will use set_index to make the "id" column our index labels and then we can use loc to select specific rows or slices of rows based on label or iloc to select based on integer position. Read more about loc and iloc [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html)

# %%
df = df.set_index("id")

#TODO: select the row labeled 282614216
df.loc[282614216]
#TODO: select the 20th row using iloc
df.iloc[19]
# Out:
# Unnamed: 0                                     21
# track_name          Crash Bandicoot Nitro Kart 3D
# size_bytes                               10735026
# currency                                      USD
# price                                        2.99
# rating_count_tot                            31456
# rating_count_ver                             4178
# user_rating                                   4.0
# user_rating_ver                               3.5
# ver                                         1.0.0
# cont_rating                                    4+
# prime_genre                                 Games
# sup_devices.num                                47
# ipadSc_urls.num                                 0
# lang.num                                        1
# vpp_lic                                         1
# test                                            0
# Name: 285005463, dtype: object

# %% [markdown]
# You may have noticed that the resulting object type of loc and iloc is not a dataframe but a series, a series is a 1-d labeled array, dataframes are acutally composed of series, with each row and column being a series, for more info on dataframes and series read [this article](https://towardsdatascience.com/pandas-series-dataframe-explained-a178f9748d46)

# %% [markdown]
# Sometimes we may want to select data based on some sort of boolean condition, for example we want all the apps from the "Shopping" genere. To do this we can use basic comparison operators < > <= >= == and boolean operators & (and) | or to select the desired data.
#
# [This article](https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9) is a great summary of all the selection techniques (boolean selection towards the end)

# %%
df[df["prime_genre"] == "Shopping"]
#TODO: select all the apps that are more than 3 dollars
df[df["price"] > 3]
#TODO: select all the apps that have less than 30 ratings for the current version or are rated less than 3.0
df[(df["rating_count_tot"] < 30) | (df["user_rating"] < 3.0)]
# Out:
#             Unnamed: 0                                         track_name  \
# id
# 286070473           25                          Mileage Log | Fahrtenbuch
# 303849934           99                                     Beer Pong Game
# 306375551          110                                         Wind Meter
# 319881193          182  Grindr - Gay and same sex guys chat, meet and ...
# 324887734          203                                        McDo France
# ...                ...                                                ...
# 1186384912       11060       Demolition Derby Virtual Reality (VR) Racing
# 1187128255       11074                         飞刀传奇-动作武侠热血江湖即时PK传奇（登录爆金装）
# 1187282363       11079                         Plead the Fifth - The Game
# 1187779532       11087              Bret Michaels Emojis + Lyric Keyboard
# 1188375727       11097                       Escape the Sweet Shop Series
#
#             size_bytes currency  price  rating_count_tot  rating_count_ver  \
# id
# 286070473     71203840      USD   5.99                 8                 0
# 303849934    188956672      USD   0.00            187315                 9
# 306375551      5234688      USD   0.99               338                12
# 319881193     80409600      USD   0.00             23201                14
# 324887734     37001216      USD   0.00                22                 0
# ...                ...      ...    ...               ...               ...
# 1186384912   168774656      USD   0.00                18                18
# 1187128255   537462784      USD   0.99                 0                 0
# 1187282363    27853824      USD   2.99                11                 0
# 1187779532   111322112      USD   1.99                15                 0
# 1188375727    90898432      USD   0.00                 3                 3
#
#             user_rating  user_rating_ver       ver cont_rating  \
# id
# 286070473           4.5              0.0     9.0.5          4+
# 303849934           2.0              4.0  17.05.15         17+
# 306375551           2.5              2.0       5.0          4+
# 319881193           2.5              2.0     3.9.1         17+
# 324887734           3.5              0.0    4.0.16          4+
# ...                 ...              ...       ...         ...
# 1186384912          4.0              4.0     1.0.0         12+
# 1187128255          0.0              0.0     2.1.0          9+
# 1187282363          4.0              0.0     1.1.1         17+
# 1187779532          4.5              0.0     1.0.2          9+
# 1188375727          5.0              5.0       1.0          4+
#
#                   prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# id
# 286070473            Business               37                5         3
# 303849934               Games               37                5         9
# 306375551             Weather               43                0         1
# 319881193   Social Networking               37                5         5
# 324887734        Food & Drink               37                0        30
# ...                       ...              ...              ...       ...
# 1186384912              Games               38                4         1
# 1187128255              Games               38                5         1
# 1187282363              Games               37                0         1
# 1187779532          Utilities               37                1         1
# 1188375727              Games               40                0         2
#
#             vpp_lic  test
# id
# 286070473         1     0
# 303849934         1     0
# 306375551         1     0
# 319881193         1     0
# 324887734         1     0
# ...             ...   ...
# 1186384912        1     0
# 1187128255        1     0
# 1187282363        1     0
# 1187779532        1     0
# 1188375727        1     0
#
# [2095 rows x 17 columns]

# %% [markdown]
# apply is used to apply a function efficiently to rows in a dataframe, it's useful to generating new columns of data or for formatting data nicely, for example you could apply to make a new column that expresses the bytes column in terms of megabytes to make it more readable, check out [this article](https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff) for some nice visuals and explanation of apply()

# %%
import numpy as np #we will learn more about numpy soon!
def byte_resizer(data):
    return np.around(data / 1000000, decimals=2)

df["size_Mb"] = df["size_bytes"].apply(byte_resizer)

#You can also use some built in functions to peform certain functions on columns
#let's say we want to get the average number of bytes:

df["size_bytes"].mean()
# Out:
# 199134453.825066

# %% [markdown]
# Groupby is used to easily split data into groups. For example let's say we want to look at the average byte size for each genre, we could do that using the code below:
#
# check out [this article](https://naomi-fridman.medium.com/pandas-groupby-explained-with-titanic-6a1c47eb8182) for more detailed information on how groupby works!

# %%
df.groupby("prime_genre")["size_bytes"].hist()
# Out:
# prime_genre
# Book                 AxesSubplot(0.125,0.125;0.775x0.755)
# Business             AxesSubplot(0.125,0.125;0.775x0.755)
# Catalogs             AxesSubplot(0.125,0.125;0.775x0.755)
# Education            AxesSubplot(0.125,0.125;0.775x0.755)
# Entertainment        AxesSubplot(0.125,0.125;0.775x0.755)
# Finance              AxesSubplot(0.125,0.125;0.775x0.755)
# Food & Drink         AxesSubplot(0.125,0.125;0.775x0.755)
# Games                AxesSubplot(0.125,0.125;0.775x0.755)
# Health & Fitness     AxesSubplot(0.125,0.125;0.775x0.755)
# Lifestyle            AxesSubplot(0.125,0.125;0.775x0.755)
# Medical              AxesSubplot(0.125,0.125;0.775x0.755)
# Music                AxesSubplot(0.125,0.125;0.775x0.755)
# Navigation           AxesSubplot(0.125,0.125;0.775x0.755)
# News                 AxesSubplot(0.125,0.125;0.775x0.755)
# Photo & Video        AxesSubplot(0.125,0.125;0.775x0.755)
# Productivity         AxesSubplot(0.125,0.125;0.775x0.755)
# Reference            AxesSubplot(0.125,0.125;0.775x0.755)
# Shopping             AxesSubplot(0.125,0.125;0.775x0.755)
# Social Networking    AxesSubplot(0.125,0.125;0.775x0.755)
# Sports               AxesSubplot(0.125,0.125;0.775x0.755)
# Travel               AxesSubplot(0.125,0.125;0.775x0.755)
# Utilities            AxesSubplot(0.125,0.125;0.775x0.755)
# Weather              AxesSubplot(0.125,0.125;0.775x0.755)
# Name: size_bytes, dtype: object

# %% [markdown]
# We can combine a number of the commands we have learned so far to find the answers to even more interesting questions! For example here's one way we could combine several commands to see the average current version rating for apps costing more than $20 in each genre!

# %%
df[(df["price"] > 20.0) & (df["currency"] == "USD")].groupby("prime_genre")["user_rating_ver"].mean()
# Out:
# prime_genre
# Book             4.500000
# Business         4.750000
# Education        2.600000
# Food & Drink     4.000000
# Games            2.833333
# Medical          3.625000
# Music            4.500000
# Navigation       1.250000
# Photo & Video    0.000000
# Productivity     3.166667
# Reference        0.000000
# Utilities        0.000000
# Name: user_rating_ver, dtype: float64

# %% [markdown]
# value counts
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# In addition to viewing tables of data we can also use some of the cool built in a external tools to
# visualize our data with charts!
#
# One of the primary libraries is called Seaborn, check out [this series of articles](https://medium.com/@neuralnets/data-visualization-with-python-and-seaborn-part-1-29c9478a8700) for a super in depth explanation of the different types of charts you can build
#
#
# Here are the types of plots we talked about previously, code examples for each are at the bottom of the page:
#
#
#
#
# 1. [histogram](https://seaborn.pydata.org/generated/seaborn.histplot.html)
# 2. [bar plot](https://seaborn.pydata.org/generated/seaborn.barplot.html)
# 3. [scatter](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)
#
# Here are some useful new ones to check out as well!
# 4. [strip](https://seaborn.pydata.org/generated/seaborn.stripplot.html)
# 5. [violin](https://seaborn.pydata.org/generated/seaborn.violinplot.html)

# %% [markdown]
# Now that we have reviewed several important data manipulation and visualization basics let's put them into practice. Use your analysis skills to answer the following questions:
#
#
#
# 1.   What are the top ten highest rated free to play apps?
# 2.   What genre has the most apps?
# 4.   What is the average cost for each genre?
# 5.   What is the average size for for each genre for apps rated 4.0 or higher?
# 6.   Compare number of supported languages and rating, is there any sort of relationship?
# 7. What is the average USD price by Genre for apps rated higher than 2.0?

# %%
#TODO: write your analysis code here
import seaborn as sns

from matplotlib import rcParams
rcParams['figure.figsize'] = 20,8.27

df
# Out:
#             Unnamed: 0                                         track_name  \
# id
# 281656475            1                                    PAC-MAN Premium
# 281796108            2                          Evernote - stay organized
# 281940292            3    WeatherBug - Local Weather, Radar, Maps, Alerts
# 282614216            4  eBay: Best App to Buy, Sell, Save! Online Shop...
# 282935706            5                                              Bible
# ...                ...                                                ...
# 1187617475       11081                                              Kubik
# 1187682390       11082                                  VR Roller-Coaster
# 1187779532       11087              Bret Michaels Emojis + Lyric Keyboard
# 1187838770       11089          VR Roller Coaster World - Virtual Reality
# 1188375727       11097                       Escape the Sweet Shop Series
#
#             size_bytes currency  price  rating_count_tot  rating_count_ver  \
# id
# 281656475    100788224      USD   3.99             21292                26
# 281796108    158578688      USD   0.00            161065                26
# 281940292    100524032      USD   0.00            188583              2822
# 282614216    128512000      USD   0.00            262241               649
# 282935706     92774400      USD   0.00            985920              5320
# ...                ...      ...    ...               ...               ...
# 1187617475   126644224      USD   0.00               142                75
# 1187682390   120760320      USD   0.00                30                30
# 1187779532   111322112      USD   1.99                15                 0
# 1187838770    97235968      USD   0.00                85                32
# 1188375727    90898432      USD   0.00                 3                 3
#
#             user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# id
# 281656475           4.0              4.5   6.3.5          4+         Games
# 281796108           4.0              3.5   8.2.2          4+  Productivity
# 281940292           3.5              4.5   5.0.0          4+       Weather
# 282614216           4.0              4.5  5.10.0         12+      Shopping
# 282935706           4.5              5.0   7.5.1          4+     Reference
# ...                 ...              ...     ...         ...           ...
# 1187617475          4.5              4.5     1.3          4+         Games
# 1187682390          4.5              4.5     0.9          4+         Games
# 1187779532          4.5              0.0   1.0.2          9+     Utilities
# 1187838770          4.5              4.5  1.0.15         12+         Games
# 1188375727          5.0              5.0     1.0          4+         Games
#
#             sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  test  size_Mb
# id
# 281656475                38                5        10        1     0   100.79
# 281796108                37                5        23        1     0   158.58
# 281940292                37                5         3        1     0   100.52
# 282614216                37                5         9        1     0   128.51
# 282935706                37                5        45        1     0    92.77
# ...                     ...              ...       ...      ...   ...      ...
# 1187617475               38                5         1        1     0   126.64
# 1187682390               38                0         1        1     0   120.76
# 1187779532               37                1         1        1     0   111.32
# 1187838770               38                0         2        1     0    97.24
# 1188375727               40                0         2        1     0    90.90
#
# [7197 rows x 18 columns]

# %%
df[df["price"] == 0].sort_values(by="user_rating", ascending=False).head(10)
# Out:
#             Unnamed: 0                                         track_name  \
# id
# 1014277964        4952                                         SelfieCity
# 969447060         4239            Eye Training Cocololo-3dステレオグラム視力回復アプリ-
# 994905763         4658                 Triller - Music Video & Film Maker
# 993492744         4642                                          Egg, Inc.
# 993071546         4631                                     小咖秀-全民视频才艺直播社区
# 992421775         4617  Patternator Pattern Maker Backgrounds & Wallpa...
# 987732117         4529               DANDY DUNGEON Legend of Brave Yamada
# 986540048         4515           Ab & Core Sworkit - Free Workout Trainer
# 985653378         4502                                  Cookie Clickers 2
# 983826477         4476            Productive habits & daily goals tracker
#
#             size_bytes currency  price  rating_count_tot  rating_count_ver  \
# id
# 1014277964    71816192      USD    0.0               252                 1
# 969447060     66277376      USD    0.0                 6                 3
# 994905763     87287808      USD    0.0             25683               186
# 993492744     53579776      USD    0.0             79074              8442
# 993071546    101220352      USD    0.0                66                 1
# 992421775     47943680      USD    0.0              2092               625
# 987732117    247331840      USD    0.0              1204                46
# 986540048     59845632      USD    0.0              2901               744
# 985653378     63004672      USD    0.0              2912               203
# 983826477      9256960      USD    0.0              4736              1519
#
#             user_rating  user_rating_ver     ver cont_rating  \
# id
# 1014277964          5.0              5.0   2.9.1          4+
# 969447060           5.0              5.0     2.2         12+
# 994905763           5.0              4.5   4.2.2         12+
# 993492744           5.0              5.0     1.5          4+
# 993071546           5.0              5.0   1.7.4         12+
# 992421775           5.0              5.0     2.1          4+
# 987732117           5.0              4.5   2.4.1          9+
# 986540048           5.0              5.0   1.3.1          4+
# 985653378           5.0              4.5  1.12.0          4+
# 983826477           5.0              5.0   1.3.4          4+
#
#                  prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# id
# 1014277964     Photo & Video               37                0         5
# 969447060            Medical               37                0         1
# 994905763      Photo & Video               37                5         1
# 993492744              Games               38                4         1
# 993071546      Entertainment               37                5         3
# 992421775      Photo & Video               37                5        12
# 987732117              Games               38                5         2
# 986540048   Health & Fitness               37                5        12
# 985653378              Games               38                5         8
# 983826477       Productivity               38                0         1
#
#             vpp_lic  test  size_Mb
# id
# 1014277964        1     0    71.82
# 969447060         1     0    66.28
# 994905763         1     0    87.29
# 993492744         1     0    53.58
# 993071546         1     0   101.22
# 992421775         1     0    47.94
# 987732117         1     0   247.33
# 986540048         1     0    59.85
# 985653378         1     0    63.00
# 983826477         1     0     9.26

# %%
# df["helper"] = 1
# df.groupby("prime_genre")["helper"].count()

sns.countplot(x="prime_genre", data=df)
# Out:
# <AxesSubplot:xlabel='prime_genre', ylabel='count'>

# %%
avg_df = df.groupby("prime_genre").mean()
avg_df["price"]
avg_df = avg_df.reset_index()
avg_df = avg_df.set_index("prime_genre")
avg_df.plot.bar(y='price', rot=0)
# Out:
# <AxesSubplot:xlabel='prime_genre'>

# %%
df[df["user_rating"] >= 4].groupby("prime_genre").mean()["size_Mb"]
# Out:
# prime_genre
# Book                 240.729636
# Business              65.194390
# Catalogs              78.465000
# Education            182.588566
# Entertainment        118.746169
# Finance               94.012059
# Food & Drink          81.013125
# Games                289.441552
# Health & Fitness      97.002923
# Lifestyle             78.385152
# Medical              583.508571
# Music                117.347547
# Navigation            65.457368
# News                  66.876667
# Photo & Video         74.221294
# Productivity          82.609861
# Reference            116.281429
# Shopping              99.442597
# Social Networking     86.420533
# Sports                87.397895
# Travel                82.144583
# Utilities             59.824769
# Weather               65.665000
# Name: size_Mb, dtype: float64

# %%
sns.barplot(x="user_rating", y="lang.num", data=df)
# Out:
# <AxesSubplot:xlabel='user_rating', ylabel='lang.num'>

# %%
df[(df["user_rating"] > 2) & (df["currency"] == "USD")].groupby("prime_genre").mean()["price"]
# Out:
# prime_genre
# Book                  2.775000
# Business              5.454808
# Catalogs              1.598000
# Education             4.195186
# Entertainment         0.943923
# Finance               0.545806
# Food & Drink          1.772245
# Games                 1.516201
# Health & Fitness      1.967682
# Lifestyle             1.026735
# Medical              10.169412
# Music                 4.934737
# Navigation            5.058065
# News                  0.611579
# Photo & Video         1.555223
# Productivity          4.550240
# Reference             3.800769
# Shopping              0.018774
# Social Networking     0.403333
# Sports                0.857442
# Travel                1.166154
# Utilities             1.547538
# Weather               1.747692
# Name: price, dtype: float64

# %% [markdown]
# Now that you've answered those questions come up with three questions of your own find a partner and exchange questions, paste their name and questios below and your analysis code!

# %% [markdown]
# **Partner Prompt**: Is there a correlation between number of languages in which the app is available, and price?

# %%
sns.barplot(x="lang.num", y="price", data=df)
