# %%
import pandas as pd

data_url = "https://raw.githubusercontent.com/Make-School-Courses/DS-1.1-Data-Analysis/master/Datasets/starbucks_drinkMenu_expanded.csv"
#source: https://www.kaggle.com/starbucks/starbucks-menu?select=starbucks_drinkMenu_expanded.csv

starbucks_dataframe = pd.read_csv(data_url)
starbucks_dataframe
# Out:
#               Beverage_category  ... Caffeine (mg)
# 0                        Coffee  ...           175
# 1                        Coffee  ...           260
# 2                        Coffee  ...           330
# 3                        Coffee  ...           410
# 4       Classic Espresso Drinks  ...            75
# ..                          ...  ...           ...
# 237  Frappuccino® Blended Crème  ...             0
# 238  Frappuccino® Blended Crème  ...             0
# 239  Frappuccino® Blended Crème  ...             0
# 240  Frappuccino® Blended Crème  ...             0
# 241  Frappuccino® Blended Crème  ...             0
#
# [242 rows x 18 columns]

# %% [markdown]
# Bar charts, otherwise known as bar graphs, bar plots, or histograms (you may have heard of those!) are very simple visualizations that allow you to plot categorical or quantitative data in a visually separable manner.
#
# Let's start by playing with the simpler of the two to visualize with bar charts: categorical data.

# %% [markdown]
# Categorical Data: variables that represent data that can be divided into groups
# Continuous Data: quantity

# %%
import seaborn as sns
from matplotlib import rcParams
#bar chart with categorical data

rcParams['figure.figsize'] = 20,8.27

#Beverage category counts for drinks with more than 100 calories?
drinks_greater_100_df = starbucks_dataframe[starbucks_dataframe["Calories"] > 100]

sns.countplot(x="Beverage_category", palette="spring", data=drinks_greater_100_df)

# %%
#what about continuous data?
starbucks_dataframe["Calories"].hist(bins=16)

# %%
#starbucks_dataframe[" Sugars (g)"]

sns.barplot(x="Beverage_category", y=" Sugars (g)", data=starbucks_dataframe)

starbucks_dataframe = starbucks_dataframe.dropna()
# starbucks_dataframe = starbucks_dataframe[(starbucks_dataframe['Caffeine (mg)'] != 'Varies') & (starbucks_dataframe['Caffeine (mg)'] != 'varies')]
starbucks_dataframe = starbucks_dataframe[starbucks_dataframe['Caffeine (mg)'].astype(str).str.isnumeric()]

def toInt(num):
  return int(num)

# starbucks_dataframe['Caffeine (mg)'] = starbucks_dataframe['Caffeine (mg)'].apply(toInt)
drinks_with_Caffeine = starbucks_dataframe[starbucks_dataframe['Caffeine (mg)'] > 50]

sns.barplot(x='Beverage_category',y='Caffeine (mg)', data=drinks_with_Caffeine)

# %% [markdown]
# With scatter plots, we can see the spread and distribution of data much more clearly.
#
# These two concepts are incredibly important to the study of descriptive statistics and the foundations of data science.
#
# We'll dive much deeper into the concepts in later classes, but we may begin exploring them now.

# %%
#scatter plot
sns.regplot(x="Calories", y=" Sugars (g)", fit_reg=True, data=starbucks_dataframe)

# %%
#strip plot

# %%
#swarm plot

# %%
#line graph

# %%
#So many more!

# %%
#more pandas commands

#commands we learned before
#.loc & iloc
#head(n) tail(n)
#set_index() specify column to be the index labels
# [] < > <= >= == & and | or, (condition) & (condition)
#columns, dtypes
#series vs. dataframe
#df[["col", "col2"]]

starbucks_dataframe["Calories"].isna().sum()

titanic_df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv")
titanic_df["age"].isna().sum()
titanic_df = titanic_df.dropna()
titanic_df

#value counts
starbucks_dataframe["Calories"].value_counts()
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 6           0       1    male  54.0  ...     E  Southampton     no   True
# 10          1       3  female   4.0  ...     G  Southampton    yes  False
# 11          1       1  female  58.0  ...     C  Southampton    yes   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 871         1       1  female  47.0  ...     D  Southampton    yes  False
# 872         0       1    male  33.0  ...     B  Southampton     no   True
# 879         1       1  female  56.0  ...     C    Cherbourg    yes  False
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
#
# [182 rows x 15 columns]

# %%
#apply

def double(num):
  return 2 * num

starbucks_dataframe["Calories_doubled"] = starbucks_dataframe["Calories"].apply(double)
#making a new column

starbucks_dataframe.drop("Calories_doubled", axis=1, inplace=True)
starbucks_dataframe
# Out:
#               Beverage_category  ... Caffeine (mg)
# 0                        Coffee  ...           175
# 1                        Coffee  ...           260
# 2                        Coffee  ...           330
# 3                        Coffee  ...           410
# 4       Classic Espresso Drinks  ...            75
# ..                          ...  ...           ...
# 237  Frappuccino® Blended Crème  ...             0
# 238  Frappuccino® Blended Crème  ...             0
# 239  Frappuccino® Blended Crème  ...             0
# 240  Frappuccino® Blended Crème  ...             0
# 241  Frappuccino® Blended Crème  ...             0
#
# [242 rows x 18 columns]

# %%
#groupby
